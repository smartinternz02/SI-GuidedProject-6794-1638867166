# %%
7**4
# Out:
# 2401

# %%
s = "Hi there Sam!"
x= s.split()
print(x)
# Out:
# ['Hi', 'there', 'Sam!']

# %%
planet = "Earth"
diameter = 12742
print("The diameter of {} is {} kilometers.".format(planet, diameter))
# Out:
# The diameter of Earth is 12742 kilometers.

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
print(lst[3][1][2][0])
# Out:
# hello

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
print(d['k1'][3]["tricky"][3]['target'][3])
# Out:
# hello

# %%
* Tuple is immutable and list is mutable
* Tuple is denoted by () and list is denoted by []

# %%
def displayDomain(email):
    print("Your Domain : " + email.split('@')[-1])
email = input("Please enter your email: >")
displayDomain(email)
# Out:
# Please enter your email: > jofu@gmail.com
# Your Domain : gmail.com

# %%
def findWord(str):
    if 'dog' in str.lower():
        print("True")
    else:
        print("False")

str = input("Please enter a string :")
findWord(str)
# Out:
# Please enter a string : dog
# True

# %%
seq = ['soup','dog','salad','cat','great']
x=filter(lambda word: word[0]=='s',seq)
print(list(x))
# Out:
# ['soup', 'salad']

# %%
def speed(s,b):
    if s<=60:
        print("NoTicket")
    elif s>61 and s<=80:
        print("Small Ticket")
    elif s>80:
        print("Big Ticket")

s=int(input("Enter speed"))
b=bool(input("Is it your birthday? (0/1)"))
if(b==1):
    s=s-5
    speed(s,b)
else:
    speed(s,b)
# Out:
# Enter speed 80
# Is it your birthday? (0/1) 1
# Small Ticket
